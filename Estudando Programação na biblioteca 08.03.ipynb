# %% [markdown]
# Meu primeiro programa

# %%
print("Hello World")
# Out:
# Hello World

# %%
print ("123")
# Out:
# 123

# %%
print ("texto")
# Out:
# texto

# %%
print("1+1")
print(1.48997*10.17)
# Out:
# 1+1
# 15.1529949

# %%
print("aula" in "mais tarde tem aula de programação")
print("a aula " + "de programação " + "Começara no horario")
# Out:
# True
# a aula de programação Começara no horario

# %%
faturamento = 2715
custo = 285
lucro = faturamento - custo
print (lucro)
# Out:
# 2430

# %%
nome = input('Qual é seu nome?')
sobrenome = input('E seu sobrenome?')
print (nome + ' ' + sobrenome)
# Out:
# Daniel Luis

# %% [markdown]
# <a href="https://colab.research.google.com/github/D-ANIELLUIS/AlgoritmoeEstruturadeDadosEngSanitria/blob/main/01_hello_world.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Meu primeiro programa

# %%
#Imprime "Hello, World" na tela
print("Hello, World")
# Out:
# Hello, World

# %%
#Variáveis em Python
#Atribuindo a string "Hello, World" a variável message
message = "Hello, World!"
#Imprimir o conteúdo da variável message
print (message)
# Out:
# Hello, World!
